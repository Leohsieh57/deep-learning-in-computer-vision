# %%
import dann_dual_model as dannd
import training_helper as th
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import glob
import os
import numpy as np
from PIL import Image
import torchvision.models as models
import copy
from torchvision.utils import save_image
import PIL
import time

# %%
device = th.getCudaDevice(cudaNum = 0, torchSeed = 123)
batch_size = 128
n_epoch = 10
my_net = dannd.CNNModel().to(device)
optimizer = optim.Adam(my_net.parameters(), lr=1e-4, betas = (0.5, 0.999))
loss_class = torch.nn.NLLLoss().to(device)
loss_domain = torch.nn.NLLLoss().to(device)
# Out:
# Device used: cuda:0

# %%
img_transform = transforms.Compose([
    transforms.Resize(28),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.1307,), std=(0.3081,))
])

mnist_train = th.labelImgData(root='hw3_data/digits/mnistm/train', transform=img_transform)
mnist_test = th.labelImgData(root='hw3_data/digits/mnistm/test', transform=img_transform)
svhn_train = th.labelImgData(root='hw3_data/digits/svhn/train', transform=img_transform)
svhn_test = th.labelImgData(root='hw3_data/digits/svhn/test', transform=img_transform)
usps_train = th.labelImgData(root='hw3_data/digits/usps/train', transform=img_transform)
usps_test = th.labelImgData(root='hw3_data/digits/usps/test', transform=img_transform)

mnist_train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, num_workers=0)
mnist_test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=False, num_workers=0)
svhn_train_loader = DataLoader(svhn_train, batch_size=batch_size, shuffle=True, num_workers=0)
svhn_test_loader = DataLoader(svhn_test, batch_size=batch_size, shuffle=False, num_workers=0)
usps_train_loader = DataLoader(usps_train, batch_size=batch_size, shuffle=True, num_workers=0)
usps_test_loader = DataLoader(usps_test, batch_size=batch_size, shuffle=False, num_workers=0)

# %%
def test(dataloader, domain= 'target'):
    my_net.eval()
    correct = 0
    for batch_idx, (img, label) in enumerate(dataloader):
        img, label = img.to(device), label.to(device)
        output, _ = my_net(img, domain = domain)
        _, pred = torch.max(output, 1)
        correct += (pred == label).sum()
    my_net.train()
    return correct.item() / len(dataloader.dataset) 

def train(filename):
    source_train, source_test = source
    target_train, target_test = target
    best_acc = test(target_test)
    print('*****Target Accuracy: {:.4f}'.format(best_acc),'\n')
    for epoch in range(n_epoch):
        len_dataloader = min(len(source_train), len(target_train))
        data_source_iter, data_target_iter = iter(source_train), iter(target_train)
        for batch_idx in range(len_dataloader):
            # calculate lambda
            p = float(batch_idx + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # training model using source data
            s_img, s_label = data_source_iter.next()
            s_img, s_label = s_img.to(device), s_label.to(device)
            my_net.zero_grad()
            domain_label_src = torch.zeros(len(s_label)).long().to(device)
            class_output, domain_output_src = my_net(s_img, alpha=alpha, domain = 'source')
            err_s_label = loss_class(class_output, s_label)
            err_s_domain = loss_domain(domain_output_src, domain_label_src)

            # training model using target data
            t_img, _ = data_target_iter.next()
            t_img = t_img.to(device)
            domain_label_tgt = torch.ones(len(t_img)).long().to(device)
            _, domain_output_tgt = my_net(t_img, alpha=alpha, domain = 'target')
            err_t_domain = loss_domain(domain_output_tgt, domain_label_tgt)
            
            # cross
            class_output_x, _ = my_net(s_img, alpha=alpha, domain = 'target')
            err_x_label = loss_class(class_output_x, s_label)
            
            err =  err_x_label + err_t_domain  + alpha*(err_s_label+ err_s_domain)
            err.backward()
            optimizer.step()
            if batch_idx % max(1, int(len_dataloader/3)) == 0:
                print('Epoch: {}/{}\t[Iter: {}/{} ({}%)]\ts_d: {:.4f}\tt_d: {:.4f}\ts_l: {:.4f}\tx_l: {:.4f}'.format(
                      epoch+1, n_epoch, batch_idx, len_dataloader, int(batch_idx*100/len_dataloader), err_s_domain, err_t_domain,
                      err_s_label, err_x_label))
        target_acc = test(target_test)
        print('*****Source Accuracy: {:.4f}\n*****Target Accuracy: {:.4f}'.format(test(source_test, domain = 'source'), target_acc),'\n')
        if target_acc > best_acc:
            best_acc = target_acc
            th.saveModel(filename+'_best.pth', my_net, optimizer)
    th.saveModel(filename+'_final.pth', my_net, optimizer)

# %%
# usps->mnistm
source = usps_train_loader, usps_test_loader
target = mnist_train_loader, mnist_test_loader
filename = 'p4_usps->mnistm'
th.loadModel(filename+'_best.pth', my_net, optimizer)
train(filename)
# Out:
# model loaded from p4_usps->mnistm_best.pth
# *****Target Accuracy: 0.5101
#
# Epoch: 1/10	[Iter: 0/57 (0%)]	s_d: 0.6295	t_d: 0.6182	s_l: 0.2080	x_l: 0.0563
# Epoch: 1/10	[Iter: 19/57 (33%)]	s_d: 0.8509	t_d: 0.4094	s_l: 0.1463	x_l: 0.0954
# Epoch: 1/10	[Iter: 38/57 (66%)]	s_d: 1.0736	t_d: 0.2852	s_l: 0.0571	x_l: 0.0315
# *****Source Accuracy: 0.9581
# *****Target Accuracy: 0.4904
#
# Epoch: 2/10	[Iter: 0/57 (0%)]	s_d: 1.1455	t_d: 0.2828	s_l: 0.0631	x_l: 0.0381
# Epoch: 2/10	[Iter: 19/57 (33%)]	s_d: 1.0389	t_d: 0.3034	s_l: 0.0840	x_l: 0.0468
# Epoch: 2/10	[Iter: 38/57 (66%)]	s_d: 0.9232	t_d: 0.3711	s_l: 0.0743	x_l: 0.0411
# *****Source Accuracy: 0.9576
# *****Target Accuracy: 0.4952
#
# Epoch: 3/10	[Iter: 0/57 (0%)]	s_d: 0.8224	t_d: 0.4290	s_l: 0.2179	x_l: 0.1535
# Epoch: 3/10	[Iter: 19/57 (33%)]	s_d: 0.7301	t_d: 0.4963	s_l: 0.0892	x_l: 0.0580
# Epoch: 3/10	[Iter: 38/57 (66%)]	s_d: 0.6732	t_d: 0.5317	s_l: 0.1566	x_l: 0.0611
# *****Source Accuracy: 0.9557
# *****Target Accuracy: 0.4852
#
# Epoch: 4/10	[Iter: 0/57 (0%)]	s_d: 0.6795	t_d: 0.5442	s_l: 0.1278	x_l: 0.0575
# Epoch: 4/10	[Iter: 19/57 (33%)]	s_d: 0.6580	t_d: 0.5656	s_l: 0.1520	x_l: 0.0695
# Epoch: 4/10	[Iter: 38/57 (66%)]	s_d: 0.6522	t_d: 0.6081	s_l: 0.1067	x_l: 0.0556
# *****Source Accuracy: 0.9552
# *****Target Accuracy: 0.4966
#
# Epoch: 5/10	[Iter: 0/57 (0%)]	s_d: 0.6274	t_d: 0.6080	s_l: 0.1699	x_l: 0.0536
# Epoch: 5/10	[Iter: 19/57 (33%)]	s_d: 0.6062	t_d: 0.6413	s_l: 0.0997	x_l: 0.0553
# Epoch: 5/10	[Iter: 38/57 (66%)]	s_d: 0.6107	t_d: 0.5974	s_l: 0.0429	x_l: 0.0145
# *****Source Accuracy: 0.9542
# *****Target Accuracy: 0.4877
#
# Epoch: 6/10	[Iter: 0/57 (0%)]	s_d: 0.6523	t_d: 0.6068	s_l: 0.1143	x_l: 0.0159
# Epoch: 6/10	[Iter: 19/57 (33%)]	s_d: 0.6592	t_d: 0.5960	s_l: 0.0787	x_l: 0.0187
# Epoch: 6/10	[Iter: 38/57 (66%)]	s_d: 0.6368	t_d: 0.6156	s_l: 0.1101	x_l: 0.0316
# *****Source Accuracy: 0.9586
# *****Target Accuracy: 0.4892
#
# Epoch: 7/10	[Iter: 0/57 (0%)]	s_d: 0.6304	t_d: 0.6172	s_l: 0.1536	x_l: 0.0677
# Epoch: 7/10	[Iter: 19/57 (33%)]	s_d: 0.6190	t_d: 0.6425	s_l: 0.0847	x_l: 0.0410
# Epoch: 7/10	[Iter: 38/57 (66%)]	s_d: 0.6296	t_d: 0.6048	s_l: 0.0929	x_l: 0.0255
# *****Source Accuracy: 0.9596
# *****Target Accuracy: 0.4960
#
# Epoch: 8/10	[Iter: 0/57 (0%)]	s_d: 0.6539	t_d: 0.6182	s_l: 0.1771	x_l: 0.0643
# Epoch: 8/10	[Iter: 19/57 (33%)]	s_d: 0.6405	t_d: 0.6256	s_l: 0.1291	x_l: 0.0365
# Epoch: 8/10	[Iter: 38/57 (66%)]	s_d: 0.6212	t_d: 0.6408	s_l: 0.1021	x_l: 0.0410
# *****Source Accuracy: 0.9601
# *****Target Accuracy: 0.4875
#
# Epoch: 9/10	[Iter: 0/57 (0%)]	s_d: 0.6028	t_d: 0.6367	s_l: 0.1706	x_l: 0.0298
# Epoch: 9/10	[Iter: 19/57 (33%)]	s_d: 0.6056	t_d: 0.5984	s_l: 0.0824	x_l: 0.0189
# Epoch: 9/10	[Iter: 38/57 (66%)]	s_d: 0.6315	t_d: 0.6135	s_l: 0.1288	x_l: 0.0571
# *****Source Accuracy: 0.9571
# *****Target Accuracy: 0.5122
#
# model saved to p4_usps->mnistm_best.pth
# Epoch: 10/10	[Iter: 0/57 (0%)]	s_d: 0.6160	t_d: 0.6051	s_l: 0.1524	x_l: 0.0171
# Epoch: 10/10	[Iter: 19/57 (33%)]	s_d: 0.6232	t_d: 0.6114	s_l: 0.0985	x_l: 0.0419
# Epoch: 10/10	[Iter: 38/57 (66%)]	s_d: 0.6515	t_d: 0.6379	s_l: 0.1263	x_l: 0.0857
# *****Source Accuracy: 0.9512
# *****Target Accuracy: 0.5018
#
# model saved to p4_usps->mnistm_final.pth

# %%
# svhn->usps
source = svhn_train_loader, svhn_test_loader
target = usps_train_loader, usps_test_loader
filename = 'p4_svhn->usps'
th.loadModel(filename+'_final.pth', my_net, optimizer)
train(filename)
# Out:
# model loaded from p4_svhn->usps_final.pth
# *****Target Accuracy: 0.5112
#
# Epoch: 1/10	[Iter: 0/57 (0%)]	s_d: 0.5940	t_d: 0.5807	s_l: 0.5285	x_l: 0.4086
# Epoch: 1/10	[Iter: 19/57 (33%)]	s_d: 1.8815	t_d: 0.1047	s_l: 0.5167	x_l: 0.5175
# Epoch: 1/10	[Iter: 38/57 (66%)]	s_d: 1.1876	t_d: 0.2358	s_l: 0.4405	x_l: 0.3740
# *****Source Accuracy: 0.8605
# *****Target Accuracy: 0.5690
#
# model saved to p4_svhn->usps_best.pth
# Epoch: 2/10	[Iter: 0/57 (0%)]	s_d: 0.9790	t_d: 0.2817	s_l: 0.6481	x_l: 0.6519
# Epoch: 2/10	[Iter: 19/57 (33%)]	s_d: 0.8202	t_d: 0.3805	s_l: 0.6296	x_l: 0.6261
# Epoch: 2/10	[Iter: 38/57 (66%)]	s_d: 0.7184	t_d: 0.4046	s_l: 0.6358	x_l: 0.5753
# *****Source Accuracy: 0.8490
# *****Target Accuracy: 0.5152
#
# Epoch: 3/10	[Iter: 0/57 (0%)]	s_d: 0.6935	t_d: 0.4617	s_l: 0.5570	x_l: 0.5190
# Epoch: 3/10	[Iter: 19/57 (33%)]	s_d: 0.7159	t_d: 0.4918	s_l: 0.7062	x_l: 0.7111
# Epoch: 3/10	[Iter: 38/57 (66%)]	s_d: 0.6824	t_d: 0.5287	s_l: 0.6369	x_l: 0.5175
# *****Source Accuracy: 0.8457
# *****Target Accuracy: 0.6273
#
# model saved to p4_svhn->usps_best.pth
# Epoch: 4/10	[Iter: 0/57 (0%)]	s_d: 0.6800	t_d: 0.5712	s_l: 0.6112	x_l: 0.5208
# Epoch: 4/10	[Iter: 19/57 (33%)]	s_d: 0.5801	t_d: 0.5694	s_l: 0.5193	x_l: 0.4491
# Epoch: 4/10	[Iter: 38/57 (66%)]	s_d: 0.5694	t_d: 0.5706	s_l: 0.6837	x_l: 0.5085
# *****Source Accuracy: 0.8123
# *****Target Accuracy: 0.5864
#
# Epoch: 5/10	[Iter: 0/57 (0%)]	s_d: 0.6037	t_d: 0.6337	s_l: 0.4247	x_l: 0.4191
# Epoch: 5/10	[Iter: 19/57 (33%)]	s_d: 0.5846	t_d: 0.6072	s_l: 0.5784	x_l: 0.4816
# Epoch: 5/10	[Iter: 38/57 (66%)]	s_d: 0.6185	t_d: 0.6146	s_l: 0.8430	x_l: 0.6338
# *****Source Accuracy: 0.8108
# *****Target Accuracy: 0.6079
#
# Epoch: 6/10	[Iter: 0/57 (0%)]	s_d: 0.6606	t_d: 0.6062	s_l: 0.7270	x_l: 0.5718
# Epoch: 6/10	[Iter: 19/57 (33%)]	s_d: 0.6311	t_d: 0.5959	s_l: 0.5947	x_l: 0.5307
# Epoch: 6/10	[Iter: 38/57 (66%)]	s_d: 0.6448	t_d: 0.6131	s_l: 0.5754	x_l: 0.5533
# *****Source Accuracy: 0.8176
# *****Target Accuracy: 0.5810
#
# Epoch: 7/10	[Iter: 0/57 (0%)]	s_d: 0.6181	t_d: 0.6235	s_l: 0.5214	x_l: 0.4190
# Epoch: 7/10	[Iter: 19/57 (33%)]	s_d: 0.6880	t_d: 0.6438	s_l: 0.5733	x_l: 0.4100
# Epoch: 7/10	[Iter: 38/57 (66%)]	s_d: 0.5837	t_d: 0.5750	s_l: 0.5623	x_l: 0.5840
# *****Source Accuracy: 0.8453
# *****Target Accuracy: 0.6378
#
# model saved to p4_svhn->usps_best.pth
# Epoch: 8/10	[Iter: 0/57 (0%)]	s_d: 0.5763	t_d: 0.5927	s_l: 0.5452	x_l: 0.5991
# Epoch: 8/10	[Iter: 19/57 (33%)]	s_d: 0.5910	t_d: 0.6127	s_l: 0.7254	x_l: 0.6293
# Epoch: 8/10	[Iter: 38/57 (66%)]	s_d: 0.5763	t_d: 0.5920	s_l: 0.5854	x_l: 0.4891
# *****Source Accuracy: 0.8424
# *****Target Accuracy: 0.6831
#
# model saved to p4_svhn->usps_best.pth
# Epoch: 9/10	[Iter: 0/57 (0%)]	s_d: 0.5600	t_d: 0.5699	s_l: 0.5830	x_l: 0.6046
# Epoch: 9/10	[Iter: 19/57 (33%)]	s_d: 0.5148	t_d: 0.6303	s_l: 0.6271	x_l: 0.4820
# Epoch: 9/10	[Iter: 38/57 (66%)]	s_d: 0.6314	t_d: 0.6244	s_l: 0.7175	x_l: 0.6714
# *****Source Accuracy: 0.8344
# *****Target Accuracy: 0.6522
#
# Epoch: 10/10	[Iter: 0/57 (0%)]	s_d: 0.6548	t_d: 0.5895	s_l: 0.6955	x_l: 0.5413
# Epoch: 10/10	[Iter: 19/57 (33%)]	s_d: 0.6225	t_d: 0.5731	s_l: 0.5856	x_l: 0.4727
# Epoch: 10/10	[Iter: 38/57 (66%)]	s_d: 0.5734	t_d: 0.5865	s_l: 0.7568	x_l: 0.5981
# *****Source Accuracy: 0.8478
# *****Target Accuracy: 0.5630
#
# model saved to p4_svhn->usps_final.pth

# %%
# mnistm -> svhn
source = mnist_train_loader, mnist_test_loader
target = svhn_train_loader, svhn_test_loader
filename = 'p4_mnistm->svhn'
th.loadModel(filename+'_best.pth', my_net, optimizer)
train(filename)
# Out:
# model loaded from p4_mnistm->svhn_best.pth
# *****Target Accuracy: 0.5290
#
# Epoch: 1/10	[Iter: 0/469 (0%)]	s_d: 0.9350	t_d: 0.2608	s_l: 0.1960	x_l: 0.0811
# Epoch: 1/10	[Iter: 156/469 (33%)]	s_d: 1.3600	t_d: 0.1113	s_l: 0.1501	x_l: 0.0836
# Epoch: 1/10	[Iter: 312/469 (66%)]	s_d: 1.0087	t_d: 0.2111	s_l: 0.1458	x_l: 0.0931
# Epoch: 1/10	[Iter: 468/469 (99%)]	s_d: 0.9763	t_d: 0.3096	s_l: 0.1491	x_l: 0.1817
# *****Source Accuracy: 0.9660
# *****Target Accuracy: 0.5084
#
# Epoch: 2/10	[Iter: 0/469 (0%)]	s_d: 0.9647	t_d: 0.3083	s_l: 0.3128	x_l: 0.1205
# Epoch: 2/10	[Iter: 156/469 (33%)]	s_d: 0.8355	t_d: 0.3943	s_l: 0.1895	x_l: 0.1434
# Epoch: 2/10	[Iter: 312/469 (66%)]	s_d: 0.7616	t_d: 0.4451	s_l: 0.2208	x_l: 0.1778
# Epoch: 2/10	[Iter: 468/469 (99%)]	s_d: 0.7649	t_d: 0.4815	s_l: 0.3025	x_l: 0.3456
# *****Source Accuracy: 0.9589
# *****Target Accuracy: 0.4386
#
# Epoch: 3/10	[Iter: 0/469 (0%)]	s_d: 0.7745	t_d: 0.5000	s_l: 0.3228	x_l: 0.2647
# Epoch: 3/10	[Iter: 156/469 (33%)]	s_d: 0.6524	t_d: 0.4761	s_l: 0.2557	x_l: 0.1591
# Epoch: 3/10	[Iter: 312/469 (66%)]	s_d: 0.6729	t_d: 0.6239	s_l: 0.3243	x_l: 0.1930
# Epoch: 3/10	[Iter: 468/469 (99%)]	s_d: 0.7066	t_d: 0.5569	s_l: 0.1909	x_l: 0.1564
# *****Source Accuracy: 0.9524
# *****Target Accuracy: 0.4991
#
# Epoch: 4/10	[Iter: 0/469 (0%)]	s_d: 0.6416	t_d: 0.5704	s_l: 0.2135	x_l: 0.1603
# Epoch: 4/10	[Iter: 156/469 (33%)]	s_d: 0.6454	t_d: 0.6352	s_l: 0.2655	x_l: 0.1958
# Epoch: 4/10	[Iter: 312/469 (66%)]	s_d: 0.6409	t_d: 0.6051	s_l: 0.2040	x_l: 0.1486
# Epoch: 4/10	[Iter: 468/469 (99%)]	s_d: 0.6342	t_d: 0.5976	s_l: 0.2383	x_l: 0.1391
# *****Source Accuracy: 0.9533
# *****Target Accuracy: 0.5105
#
# Epoch: 5/10	[Iter: 0/469 (0%)]	s_d: 0.6120	t_d: 0.5301	s_l: 0.2750	x_l: 0.1885
# Epoch: 5/10	[Iter: 156/469 (33%)]	s_d: 0.6711	t_d: 0.6948	s_l: 0.2666	x_l: 0.2594
# Epoch: 5/10	[Iter: 312/469 (66%)]	s_d: 0.6068	t_d: 0.5877	s_l: 0.3114	x_l: 0.2217
# Epoch: 5/10	[Iter: 468/469 (99%)]	s_d: 0.6088	t_d: 0.6056	s_l: 0.3173	x_l: 0.2718
# *****Source Accuracy: 0.9569
# *****Target Accuracy: 0.5194
#
# Epoch: 6/10	[Iter: 0/469 (0%)]	s_d: 0.6046	t_d: 0.6631	s_l: 0.2775	x_l: 0.1618
# Epoch: 6/10	[Iter: 156/469 (33%)]	s_d: 0.5559	t_d: 0.5933	s_l: 0.1992	x_l: 0.1689
# Epoch: 6/10	[Iter: 312/469 (66%)]	s_d: 0.6201	t_d: 0.5511	s_l: 0.2975	x_l: 0.1533
# Epoch: 6/10	[Iter: 468/469 (99%)]	s_d: 0.6355	t_d: 0.6171	s_l: 0.3361	x_l: 0.1831
# *****Source Accuracy: 0.9620
# *****Target Accuracy: 0.5479
#
# model saved to p4_mnistm->svhn_best.pth
# Epoch: 7/10	[Iter: 0/469 (0%)]	s_d: 0.6328	t_d: 0.5976	s_l: 0.1339	x_l: 0.1126
# Epoch: 7/10	[Iter: 156/469 (33%)]	s_d: 0.5997	t_d: 0.5876	s_l: 0.2758	x_l: 0.2293
# Epoch: 7/10	[Iter: 312/469 (66%)]	s_d: 0.6545	t_d: 0.5705	s_l: 0.2409	x_l: 0.1150
# Epoch: 7/10	[Iter: 468/469 (99%)]	s_d: 0.5546	t_d: 0.6553	s_l: 0.2690	x_l: 0.1766
# *****Source Accuracy: 0.9574
# *****Target Accuracy: 0.5211
#
# Epoch: 8/10	[Iter: 0/469 (0%)]	s_d: 0.5694	t_d: 0.5912	s_l: 0.1646	x_l: 0.1037
# Epoch: 8/10	[Iter: 156/469 (33%)]	s_d: 0.6507	t_d: 0.6351	s_l: 0.1983	x_l: 0.1391
# Epoch: 8/10	[Iter: 312/469 (66%)]	s_d: 0.6092	t_d: 0.5975	s_l: 0.2637	x_l: 0.1653
# Epoch: 8/10	[Iter: 468/469 (99%)]	s_d: 0.6288	t_d: 0.5750	s_l: 0.3708	x_l: 0.3167
# *****Source Accuracy: 0.9588
# *****Target Accuracy: 0.5210
#
# Epoch: 9/10	[Iter: 0/469 (0%)]	s_d: 0.6890	t_d: 0.6210	s_l: 0.3056	x_l: 0.1284
# Epoch: 9/10	[Iter: 156/469 (33%)]	s_d: 0.6346	t_d: 0.6137	s_l: 0.2844	x_l: 0.2545
# Epoch: 9/10	[Iter: 312/469 (66%)]	s_d: 0.5606	t_d: 0.5707	s_l: 0.1450	x_l: 0.0826
# Epoch: 9/10	[Iter: 468/469 (99%)]	s_d: 0.5753	t_d: 0.6270	s_l: 0.2156	x_l: 0.0636
# *****Source Accuracy: 0.9625
# *****Target Accuracy: 0.5294
#
# Epoch: 10/10	[Iter: 0/469 (0%)]	s_d: 0.5556	t_d: 0.6575	s_l: 0.2213	x_l: 0.1080
# Epoch: 10/10	[Iter: 156/469 (33%)]	s_d: 0.7294	t_d: 0.6001	s_l: 0.2618	x_l: 0.1081
# Epoch: 10/10	[Iter: 312/469 (66%)]	s_d: 0.6197	t_d: 0.5601	s_l: 0.3642	x_l: 0.1247
# Epoch: 10/10	[Iter: 468/469 (99%)]	s_d: 0.5317	t_d: 0.6477	s_l: 0.1999	x_l: 0.1603
# *****Source Accuracy: 0.9413
# *****Target Accuracy: 0.5351
#
# model saved to p4_mnistm->svhn_final.pth
