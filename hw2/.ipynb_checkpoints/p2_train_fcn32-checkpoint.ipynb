# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import glob
import os
import numpy as np
from PIL import Image
import torchvision.models as models
import copy
from torchvision.utils import save_image
import PIL
import skimage.io
import multiprocessing as mp
import time

# %%
def dataType(fn):
    return fn.split('/')[-1].split('_')[0]
    
class npLoader(Dataset):
    def __init__(self, root, transform = None):
        self.transform = transform
        self.root = root
        fnList = sorted(glob.glob(os.path.join(self.root, '*.npy')))
        fnImgList = [fn for fn in fnList if dataType(fn) == 'img']
        fnMaskList = [fn for fn in fnList if dataType(fn) == 'mask']
        self.len = len(fnImgList)
        self.fnList = [(fnImgList[i], fnMaskList[i]) for i in range(self.len)]
    
    def __getitem__(self, index):
        fnImg, fnMask = self.fnList[index]
        return np.load(fnImg), np.load(fnMask)
            
    def __len__(self):
        return self.len

# %%
# parameters
train_set = npLoader(root='hw2_data/p2_data/train_npy', transform=transforms.ToTensor())
test_set = npLoader(root='hw2_data/p2_data/validation_npy', transform=transforms.ToTensor())

trainset_loader = DataLoader(train_set, batch_size=16, shuffle=True, num_workers=0)
testset_loader = DataLoader(test_set, batch_size=mp.cpu_count(), shuffle=False, num_workers=0)

criterion = nn.NLLLoss()

# %%
# activate cuda
use_cuda = torch.cuda.is_available()
torch.manual_seed(123)
device = torch.device("cuda:1" if use_cuda else "cpu")
#device = torch.device('cpu')
print('Device used:', device)
# Out:
# Device used: cuda:1

# %%
class fcn32s(nn.Module):
    def __init__(self, num_classes, pretrained = True):
        super(fcn32s, self).__init__()
        self.vgg = torchvision.models.vgg16(pretrained=True)
        self.vgg.classifier = nn.Sequential(
            nn.Conv2d(512, 4096, kernel_size=(2, 2), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.Dropout2d(),
            
            nn.Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.Dropout2d(),
            
            nn.Conv2d(4096, num_classes, kernel_size=(1, 1), stride=(1, 1)),
            nn.ConvTranspose2d(num_classes, num_classes, 64 , 32 , 0, bias=False),
        )
    def  forward (self, x) :        
        x = self.vgg.features(x)
        x = self.vgg.classifier(x)
        return x
    
class fcn16s(nn.Module):
    def __init__(self, num_classes, pretrained = True):
        super(fcn16s, self).__init__()
        self.vgg = torchvision.models.vgg16(pretrained=True)
        self.to_pool4 = nn.Sequential(*list(self.vgg.features.children())[:24])
        self.to_pool5 = nn.Sequential(*list(self.vgg.features.children())[24:])
        self.vgg.classifier = nn.Sequential(
            nn.Conv2d(512, 4096, kernel_size=(2, 2), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.Dropout2d(),
            
            nn.Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.Dropout2d(),
            
            nn.Conv2d(4096, num_classes, kernel_size=(1, 1), stride=(1, 1)),
            nn.ConvTranspose2d(num_classes, 512, 4 , 2 , 0, bias=False)
            )
        self.upsample16 = nn.ConvTranspose2d(512, num_classes, 16 , 16 , 0, bias=False)
        
    def forward (self, x) :        
        pool4_output = self.to_pool4(x) #pool4 output size torch.Size([64, 512, 16, 16])
        x = self.to_pool5(pool4_output)
        x = self.vgg.classifier(x)    # 2xconv7 output size torch.Size([64, 512, 16, 16])
        x = self.upsample16(x+pool4_output)
        return x

# %%
def save_checkpoint(checkpoint_path, model, optimizer):
    state = {'state_dict': model.state_dict(),
             'optimizer' : optimizer.state_dict()}
    torch.save(state, checkpoint_path)
    print('model saved to %s' % checkpoint_path)
    
def load_checkpoint(checkpoint_path, model, optimizer):
    state = torch.load(checkpoint_path)
    model.load_state_dict(state['state_dict'])
    optimizer.load_state_dict(state['optimizer'])
    print('model loaded from %s' % checkpoint_path)

# %%
def train_save(model, epoch, log_interval=25, save_interval = 5):
    model.train()
    optimizer = optim.Adam(model.parameters(),lr=0.0002, betas=(0.9, 0.999))
    iteration = 0
    for ep in range(epoch):
        print('')
        for batch_idx, (data, target) in enumerate(trainset_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            output = F.log_softmax(output, dim= 1)
            optimizer.zero_grad()
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            if iteration % log_interval == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    ep, batch_idx * len(data), len(trainset_loader.dataset),
                    100. * batch_idx / len(trainset_loader), loss.item()))
            iteration += 1
        if ep % save_interval == 0:
            save_checkpoint('p2_fcn32_ep'+str(ep)+'.pth', model, optimizer)
        print('')
        test(model)

# %%
def mIoU(labels, pred):
    mean_iou = 0
    for i in range(6):
        tp_fp = np.sum(pred == i)
        tp_fn = np.sum(labels == i)
        tp = np.sum((pred == i) * (labels == i))
        iou = tp / (tp_fp + tp_fn - tp)
        mean_iou += iou / 6
        print('class #%d : %1.5f'%(i, iou))
    print('\nmean_iou: %f\n' % mean_iou)
    return mean_iou


currentBestIoU = 0
def test(model, log_interval=5):
    loss, iteration = 0, 0
    model.eval()
    optimizer = optim.Adam(model.parameters(),lr=0.0002, betas=(0.9, 0.999))
    print('start testing model...')
    with torch.no_grad(): # This will free the GPU memory used for back-prop
        start = time.time()
        predList, maskList = [], []
        for data, target in testset_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            output = F.log_softmax(output, dim= 1)
            loss += criterion(output, target).item()*len(data)
            pred = output.max(1, keepdim=True)[1]
            predList += [singleBatch[0] for singleBatch in pred.cpu().numpy()]
            maskList += [singleBatch for singleBatch in target.cpu().numpy()]
            iteration += 1
    IoU = mIoU(np.array(predList), np.array(maskList))
    loss /= len(testset_loader.dataset)
    print('')
    print('Test set average loss =',loss,'     mIoU =',IoU)
    global currentBestIoU
    if IoU > currentBestIoU:
        print("current best model updated!")
        currentBestIoU = IoU
        save_checkpoint('p2_current_best_fcn32-'+str(round(IoU*100.0,2))+'.pth', model, optimizer)

# %%
model = fcn32s(7)
model.to(device)
train_save(model, 25)
# Out:
# Train Epoch: 0 [0/2000 (0%)]	Loss: 1.945906
# Train Epoch: 0 [400/2000 (20%)]	Loss: 1.306225
# Train Epoch: 0 [800/2000 (40%)]	Loss: 1.086544
# Train Epoch: 0 [1200/2000 (60%)]	Loss: 1.148957
# Train Epoch: 0 [1600/2000 (80%)]	Loss: 0.569953
# model saved to p2_fcn32_ep0.pth
#
# start testing model...
# class #0 : 0.65915
# class #1 : 0.74986
# class #2 : 0.00093
# class #3 : 0.62193
# class #4 : 0.58514
# class #5 : 0.00105
#
# mean_iou: 0.436346
#
#
# Test set average loss = 0.8112429301562476      mIoU = 0.43634566894260063
# current best model updated!
# model saved to p2_current_best_fcn32-43.63.pth
#
# Train Epoch: 1 [0/2000 (0%)]	Loss: 0.885437
# Train Epoch: 1 [400/2000 (20%)]	Loss: 0.639730
# Train Epoch: 1 [800/2000 (40%)]	Loss: 0.742051
# Train Epoch: 1 [1200/2000 (60%)]	Loss: 0.665677
# Train Epoch: 1 [1600/2000 (80%)]	Loss: 0.787337
#
# start testing model...
# class #0 : 0.68570
# class #1 : 0.74806
# class #2 : 0.00013
# class #3 : 0.70642
# class #4 : 0.64374
# class #5 : 0.00013
#
# mean_iou: 0.464029
#
#
# Test set average loss = 0.7055190574334289      mIoU = 0.4640291288485409
# current best model updated!
# model saved to p2_current_best_fcn32-46.4.pth
#
# Train Epoch: 2 [0/2000 (0%)]	Loss: 0.517663
# Train Epoch: 2 [400/2000 (20%)]	Loss: 0.681639
# Train Epoch: 2 [800/2000 (40%)]	Loss: 0.735048
# Train Epoch: 2 [1200/2000 (60%)]	Loss: 0.782365
# Train Epoch: 2 [1600/2000 (80%)]	Loss: 0.638473
#
# start testing model...
# class #0 : 0.68091
# class #1 : 0.76368
# class #2 : 0.00212
# class #3 : 0.71289
# class #4 : 0.68438
# class #5 : 0.00075
#
# mean_iou: 0.474121
#
#
# Test set average loss = 0.5971740062134739      mIoU = 0.47412079135140267
# current best model updated!
# model saved to p2_current_best_fcn32-47.41.pth
#
# Train Epoch: 3 [0/2000 (0%)]	Loss: 0.722601
# Train Epoch: 3 [400/2000 (20%)]	Loss: 0.601547
# Train Epoch: 3 [800/2000 (40%)]	Loss: 0.572558
# Train Epoch: 3 [1200/2000 (60%)]	Loss: 0.565256
# Train Epoch: 3 [1600/2000 (80%)]	Loss: 0.467686
#
# start testing model...
# class #0 : 0.62099
# class #1 : 0.81381
# class #2 : 0.00117
# class #3 : 0.67708
# class #4 : 0.69167
# class #5 : 0.22285
#
# mean_iou: 0.504597
#
#
# Test set average loss = 0.5865877259102313      mIoU = 0.5045973727174118
# current best model updated!
# model saved to p2_current_best_fcn32-50.46.pth
#
# Train Epoch: 4 [0/2000 (0%)]	Loss: 0.585532
# Train Epoch: 4 [400/2000 (20%)]	Loss: 0.547420
# Train Epoch: 4 [800/2000 (40%)]	Loss: 0.624478
# Train Epoch: 4 [1200/2000 (60%)]	Loss: 0.556176
# Train Epoch: 4 [1600/2000 (80%)]	Loss: 0.678695
#
# start testing model...
# class #0 : 0.66144
# class #1 : 0.83646
# class #2 : 0.03450
# class #3 : 0.69750
# class #4 : 0.68990
# class #5 : 0.46804
#
# mean_iou: 0.564641
#
#
# Test set average loss = 0.5124816677681667      mIoU = 0.5646408894294777
# current best model updated!
# model saved to p2_current_best_fcn32-56.46.pth
#
# Train Epoch: 5 [0/2000 (0%)]	Loss: 0.545473
# Train Epoch: 5 [400/2000 (20%)]	Loss: 0.399802
# Train Epoch: 5 [800/2000 (40%)]	Loss: 0.506385
# Train Epoch: 5 [1200/2000 (60%)]	Loss: 0.529846
# Train Epoch: 5 [1600/2000 (80%)]	Loss: 0.407482
# model saved to p2_fcn32_ep5.pth
#
# start testing model...
# class #0 : 0.58191
# class #1 : 0.83790
# class #2 : 0.08089
# class #3 : 0.75392
# class #4 : 0.67210
# class #5 : 0.55434
#
# mean_iou: 0.580177
#
#
# Test set average loss = 0.511732309940724      mIoU = 0.5801769089062648
# current best model updated!
# model saved to p2_current_best_fcn32-58.02.pth
#
# Train Epoch: 6 [0/2000 (0%)]	Loss: 0.351095
# Train Epoch: 6 [400/2000 (20%)]	Loss: 0.576835
# Train Epoch: 6 [800/2000 (40%)]	Loss: 0.382468
# Train Epoch: 6 [1200/2000 (60%)]	Loss: 0.649871
# Train Epoch: 6 [1600/2000 (80%)]	Loss: 0.668420
#
# start testing model...
# class #0 : 0.70151
# class #1 : 0.85080
# class #2 : 0.13144
# class #3 : 0.72992
# class #4 : 0.66447
# class #5 : 0.55633
#
# mean_iou: 0.605746
#
#
# Test set average loss = 0.4765738602510222      mIoU = 0.6057458613130422
# current best model updated!
# model saved to p2_current_best_fcn32-60.57.pth
#
# Train Epoch: 7 [0/2000 (0%)]	Loss: 0.499545
# Train Epoch: 7 [400/2000 (20%)]	Loss: 0.382305
# Train Epoch: 7 [800/2000 (40%)]	Loss: 0.394434
# Train Epoch: 7 [1200/2000 (60%)]	Loss: 0.436698
# Train Epoch: 7 [1600/2000 (80%)]	Loss: 0.357455
#
# start testing model...
# class #0 : 0.73947
# class #1 : 0.86396
# class #2 : 0.23730
# class #3 : 0.73642
# class #4 : 0.68962
# class #5 : 0.60667
#
# mean_iou: 0.645575
#
#
# Test set average loss = 0.4255319660971601      mIoU = 0.6455746981599567
# current best model updated!
# model saved to p2_current_best_fcn32-64.56.pth
#
# Train Epoch: 8 [0/2000 (0%)]	Loss: 0.366543
# Train Epoch: 8 [400/2000 (20%)]	Loss: 0.400698
# Train Epoch: 8 [800/2000 (40%)]	Loss: 0.425596
# Train Epoch: 8 [1200/2000 (60%)]	Loss: 0.455870
# Train Epoch: 8 [1600/2000 (80%)]	Loss: 0.329131
#
# start testing model...
# class #0 : 0.72493
# class #1 : 0.85577
# class #2 : 0.15966
# class #3 : 0.76140
# class #4 : 0.68706
# class #5 : 0.48484
#
# mean_iou: 0.612277
#
#
# Test set average loss = 0.47396564390872703      mIoU = 0.6122769492114547
#
# Train Epoch: 9 [0/2000 (0%)]	Loss: 0.357166
# Train Epoch: 9 [400/2000 (20%)]	Loss: 0.363539
# Train Epoch: 9 [800/2000 (40%)]	Loss: 0.396042
# Train Epoch: 9 [1200/2000 (60%)]	Loss: 0.357644
# Train Epoch: 9 [1600/2000 (80%)]	Loss: 0.306389
#
# start testing model...
# class #0 : 0.72482
# class #1 : 0.86811
# class #2 : 0.24696
# class #3 : 0.75803
# class #4 : 0.73106
# class #5 : 0.60873
#
# mean_iou: 0.656285
#
#
# Test set average loss = 0.4001675905652547      mIoU = 0.6562849472561311
# current best model updated!
# model saved to p2_current_best_fcn32-65.63.pth
#
# Train Epoch: 10 [0/2000 (0%)]	Loss: 0.267816
# Train Epoch: 10 [400/2000 (20%)]	Loss: 0.317439
# Train Epoch: 10 [800/2000 (40%)]	Loss: 0.401246
# Train Epoch: 10 [1200/2000 (60%)]	Loss: 0.399848
# Train Epoch: 10 [1600/2000 (80%)]	Loss: 0.262719
# model saved to p2_fcn32_ep10.pth
#
# start testing model...
# class #0 : 0.70806
# class #1 : 0.86715
# class #2 : 0.30171
# class #3 : 0.81495
# class #4 : 0.70979
# class #5 : 0.65069
#
# mean_iou: 0.675392
#
#
# Test set average loss = 0.3980095641622284      mIoU = 0.6753922846597809
# current best model updated!
# model saved to p2_current_best_fcn32-67.54.pth
#
# Train Epoch: 11 [0/2000 (0%)]	Loss: 0.333720
# Train Epoch: 11 [400/2000 (20%)]	Loss: 0.422674
# Train Epoch: 11 [800/2000 (40%)]	Loss: 0.331791
# Train Epoch: 11 [1200/2000 (60%)]	Loss: 0.196398
# Train Epoch: 11 [1600/2000 (80%)]	Loss: 0.280166
#
# start testing model...
# class #0 : 0.74426
# class #1 : 0.87452
# class #2 : 0.24741
# class #3 : 0.79591
# class #4 : 0.74109
# class #5 : 0.65815
#
# mean_iou: 0.676887
#
#
# Test set average loss = 0.3826210774800193      mIoU = 0.6768870865977584
# current best model updated!
# model saved to p2_current_best_fcn32-67.69.pth
#
# Train Epoch: 12 [0/2000 (0%)]	Loss: 0.192497
# Train Epoch: 12 [400/2000 (20%)]	Loss: 0.262679
# Train Epoch: 12 [800/2000 (40%)]	Loss: 0.642649
# Train Epoch: 12 [1200/2000 (60%)]	Loss: 0.334815
# Train Epoch: 12 [1600/2000 (80%)]	Loss: 0.259880
#
# start testing model...
# class #0 : 0.73668
# class #1 : 0.87566
# class #2 : 0.30421
# class #3 : 0.77089
# class #4 : 0.73148
# class #5 : 0.65772
#
# mean_iou: 0.679441
#
#
# Test set average loss = 0.3963335358215213      mIoU = 0.6794410030690082
# current best model updated!
# model saved to p2_current_best_fcn32-67.94.pth
#
# Train Epoch: 13 [0/2000 (0%)]	Loss: 0.262216
# Train Epoch: 13 [400/2000 (20%)]	Loss: 0.189436
# Train Epoch: 13 [800/2000 (40%)]	Loss: 0.317482
# Train Epoch: 13 [1200/2000 (60%)]	Loss: 0.337345
# Train Epoch: 13 [1600/2000 (80%)]	Loss: 0.274626
#
# start testing model...
# class #0 : 0.75101
# class #1 : 0.86952
# class #2 : 0.23421
# class #3 : 0.74819
# class #4 : 0.73656
# class #5 : 0.63789
#
# mean_iou: 0.662896
#
#
# Test set average loss = 0.4261789208256317      mIoU = 0.6628956314852853
#
# Train Epoch: 14 [0/2000 (0%)]	Loss: 0.319554
# Train Epoch: 14 [400/2000 (20%)]	Loss: 0.250832
# Train Epoch: 14 [800/2000 (40%)]	Loss: 0.249130
# Train Epoch: 14 [1200/2000 (60%)]	Loss: 0.385933
# Train Epoch: 14 [1600/2000 (80%)]	Loss: 0.261646
#
# start testing model...
# class #0 : 0.70029
# class #1 : 0.87440
# class #2 : 0.20796
# class #3 : 0.81758
# class #4 : 0.71950
# class #5 : 0.61201
#
# mean_iou: 0.655291
#
#
# Test set average loss = 0.4546733624972258      mIoU = 0.6552908553241013
#
# Train Epoch: 15 [0/2000 (0%)]	Loss: 0.237096
# Train Epoch: 15 [400/2000 (20%)]	Loss: 0.198201
# Train Epoch: 15 [800/2000 (40%)]	Loss: 0.262733
# Train Epoch: 15 [1200/2000 (60%)]	Loss: 0.203441
# Train Epoch: 15 [1600/2000 (80%)]	Loss: 0.151992
# model saved to p2_fcn32_ep15.pth
#
# start testing model...
# class #0 : 0.75034
# class #1 : 0.87556
# class #2 : 0.24596
# class #3 : 0.80932
# class #4 : 0.70858
# class #5 : 0.65686
#
# mean_iou: 0.674438
#
#
# Test set average loss = 0.4188704767811623      mIoU = 0.6744375421011026
#
# Train Epoch: 16 [0/2000 (0%)]	Loss: 0.186426
# Train Epoch: 16 [400/2000 (20%)]	Loss: 0.291123
# Train Epoch: 16 [800/2000 (40%)]	Loss: 0.148882
# Train Epoch: 16 [1200/2000 (60%)]	Loss: 0.173363
# Train Epoch: 16 [1600/2000 (80%)]	Loss: 0.133164
#
# start testing model...
# class #0 : 0.75455
# class #1 : 0.85835
# class #2 : 0.32566
# class #3 : 0.79799
# class #4 : 0.72672
# class #5 : 0.67578
#
# mean_iou: 0.689841
#
#
# Test set average loss = 0.4226918937167305      mIoU = 0.689840860112332
# current best model updated!
# model saved to p2_current_best_fcn32-68.98.pth
#
# Train Epoch: 17 [0/2000 (0%)]	Loss: 0.136679
# Train Epoch: 17 [400/2000 (20%)]	Loss: 0.141874
# Train Epoch: 17 [800/2000 (40%)]	Loss: 0.132112
# Train Epoch: 17 [1200/2000 (60%)]	Loss: 0.131721
# Train Epoch: 17 [1600/2000 (80%)]	Loss: 0.103103
#
# start testing model...
# class #0 : 0.74372
# class #1 : 0.86553
# class #2 : 0.33845
# class #3 : 0.79528
# class #4 : 0.73410
# class #5 : 0.65668
#
# mean_iou: 0.688959
#
#
# Test set average loss = 0.4189405717274558      mIoU = 0.6889590157579304
#
# Train Epoch: 18 [0/2000 (0%)]	Loss: 0.130877
# Train Epoch: 18 [400/2000 (20%)]	Loss: 0.146840
# Train Epoch: 18 [800/2000 (40%)]	Loss: 0.127702
# Train Epoch: 18 [1200/2000 (60%)]	Loss: 0.157122
# Train Epoch: 18 [1600/2000 (80%)]	Loss: 0.122829
#
# start testing model...
# class #0 : 0.72999
# class #1 : 0.87261
# class #2 : 0.31448
# class #3 : 0.77089
# class #4 : 0.73128
# class #5 : 0.63848
#
# mean_iou: 0.676289
#
#
# Test set average loss = 0.4538779540516523      mIoU = 0.6762885022612484
#
# Train Epoch: 19 [0/2000 (0%)]	Loss: 0.219747
# Train Epoch: 19 [400/2000 (20%)]	Loss: 0.131691
# Train Epoch: 19 [800/2000 (40%)]	Loss: 0.159143
# Train Epoch: 19 [1200/2000 (60%)]	Loss: 0.118661
# Train Epoch: 19 [1600/2000 (80%)]	Loss: 0.155982
#
# start testing model...
# class #0 : 0.73475
# class #1 : 0.87633
# class #2 : 0.31450
# class #3 : 0.80479
# class #4 : 0.74622
# class #5 : 0.67052
#
# mean_iou: 0.691184
#
#
# Test set average loss = 0.49057842066315827      mIoU = 0.6911841892542732
# current best model updated!
# model saved to p2_current_best_fcn32-69.12.pth
#
# Train Epoch: 20 [0/2000 (0%)]	Loss: 0.103710
# Train Epoch: 20 [400/2000 (20%)]	Loss: 0.118539

# %%
print(fcn32s(7))
# Out:
# fcn32s(
#   (vgg): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#     (classifier): Sequential(
#       (0): Conv2d(512, 4096, kernel_size=(2, 2), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Dropout2d(p=0.5, inplace=False)
#       (3): Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): Dropout2d(p=0.5, inplace=False)
#       (6): Conv2d(4096, 7, kernel_size=(1, 1), stride=(1, 1))
#       (7): ConvTranspose2d(7, 7, kernel_size=(64, 64), stride=(32, 32), bias=False)
#     )
#   )
# )
